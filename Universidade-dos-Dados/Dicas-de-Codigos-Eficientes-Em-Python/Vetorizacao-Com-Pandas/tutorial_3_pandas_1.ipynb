# %% [markdown]
# ### 1. Carregar Informações

# %%
# importar biblioteca

import pandas as pd

# %%
# Carregando os dados

fifa19 = pd.read_csv('fifa19.csv', sep=',', skiprows=None)
fifa19.head()

# Excel:
# xl = pd.ExcelFile(file) # carrega o arquivo
# df = xl.parse('Sheet1') # carrega a aba

# pd.read_csv("fifa19.csv", dtype={"Potential":"int","SlidingTackle":"float64"})
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
fifa19.tail(3)
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# 18206           165.0

# %% [markdown]
# ### 2. Informações sobre o dataset

# %%
fifa19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
#  13  Joined                    18207 non-null  int64
#  14  Contract Valid Until      17918 non-null  object
#  15  Height                    18207 non-null  float64
#  16  Weight                    18207 non-null  float64
#  17  Release Clause            18207 non-null  float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 2.5+ MB

# %%
fifa19.shape
# Out:
# (18207, 18)

# %%
fifa19.shape[0]
# Out:
# 18207

# %%
fifa19.shape[1]
# Out:
# 18

# %%
print("Temos %0.f linhas e %0.f colunas" % (fifa19.shape[0], fifa19.shape[1]))
# Out:
# Temos 18207 linhas e 18 colunas

# %%
fifa19.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
fifa19.columns[1]
# Out:
# 'Name'

# %%
fifa19.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %% [markdown]
# ### Se quiser estabelecer uma coluna como índice é só usar set_index, por exemplo:
#
#  - df.set_index('nome da coluna')  para uma coluna
#  - df.set_index(['nome da coluna 1', 'nome da coluna 2', 'nome da coluna 3', 'nome da coluna n'])  para várias colunas
#  - def.set_index((pd.index))[1,2,3,4...], 'nome do índice') # pra criar um indice novo do zero

# %%
display(fifa19.head())
display(fifa19.tail())
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18202          2.0       CM    2017           2019-01-01  5.750000   134.0
# 18203          2.0       ST    2018           2020-01-01  6.250000   170.0
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18202           143.0
# 18203           113.0
# 18204           165.0
# 18205           143.0
# 18206           165.0

# %%
pd.set_option('max_colwidth', 40)
#pd.set_option('max_rows', 100)
#pd.set_option('max_columns', 60)

pd.get_option('max_colwidth')
# Out:
# 40

# %%
def low_values_red(value):
    color = 'red' if value < 92 else 'black'
    return 'color: %s' %color

fifa19[['Overall', 'Potential']].head(10).style.applymap(low_values_red)
# Out:
# <style type="text/css">
# #T_3800e_row0_col0, #T_3800e_row0_col1, #T_3800e_row1_col0, #T_3800e_row1_col1, #T_3800e_row2_col0, #T_3800e_row2_col1, #T_3800e_row3_col1, #T_3800e_row4_col1, #T_3800e_row9_col1 {
#   color: black;
# }
# #T_3800e_row3_col0, #T_3800e_row4_col0, #T_3800e_row5_col0, #T_3800e_row5_col1, #T_3800e_row6_col0, #T_3800e_row6_col1, #T_3800e_row7_col0, #T_3800e_row7_col1, #T_3800e_row8_col0, #T_3800e_row8_col1, #T_3800e_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_3800e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3800e_level0_col0" class="col_heading level0 col0" >Overall</th>
#       <th id="T_3800e_level0_col1" class="col_heading level0 col1" >Potential</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3800e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3800e_row0_col0" class="data row0 col0" >94</td>
#       <td id="T_3800e_row0_col1" class="data row0 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3800e_row1_col0" class="data row1 col0" >94</td>
#       <td id="T_3800e_row1_col1" class="data row1 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3800e_row2_col0" class="data row2 col0" >92</td>
#       <td id="T_3800e_row2_col1" class="data row2 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3800e_row3_col0" class="data row3 col0" >91</td>
#       <td id="T_3800e_row3_col1" class="data row3 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3800e_row4_col0" class="data row4 col0" >91</td>
#       <td id="T_3800e_row4_col1" class="data row4 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3800e_row5_col0" class="data row5 col0" >91</td>
#       <td id="T_3800e_row5_col1" class="data row5 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3800e_row6_col0" class="data row6 col0" >91</td>
#       <td id="T_3800e_row6_col1" class="data row6 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3800e_row7_col0" class="data row7 col0" >91</td>
#       <td id="T_3800e_row7_col1" class="data row7 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3800e_row8_col0" class="data row8 col0" >91</td>
#       <td id="T_3800e_row8_col1" class="data row8 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_3800e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3800e_row9_col0" class="data row9 col0" >90</td>
#       <td id="T_3800e_row9_col1" class="data row9 col1" >93</td>
#     </tr>
#   </tbody>
# </table>

# %%
fifa19.head(10).style.applymap(low_values_red, subset = ['Overall', 'Potential'])
# Out:
# <style type="text/css">
# #T_cff86_row0_col4, #T_cff86_row0_col5, #T_cff86_row1_col4, #T_cff86_row1_col5, #T_cff86_row2_col4, #T_cff86_row2_col5, #T_cff86_row3_col5, #T_cff86_row4_col5, #T_cff86_row9_col5 {
#   color: black;
# }
# #T_cff86_row3_col4, #T_cff86_row4_col4, #T_cff86_row5_col4, #T_cff86_row5_col5, #T_cff86_row6_col4, #T_cff86_row6_col5, #T_cff86_row7_col4, #T_cff86_row7_col5, #T_cff86_row8_col4, #T_cff86_row8_col5, #T_cff86_row9_col4 {
#   color: red;
# }
# </style>
# <table id="T_cff86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cff86_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_cff86_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_cff86_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_cff86_level0_col3" class="col_heading level0 col3" >Nationality</th>
#       <th id="T_cff86_level0_col4" class="col_heading level0 col4" >Overall</th>
#       <th id="T_cff86_level0_col5" class="col_heading level0 col5" >Potential</th>
#       <th id="T_cff86_level0_col6" class="col_heading level0 col6" >Club</th>
#       <th id="T_cff86_level0_col7" class="col_heading level0 col7" >Value</th>
#       <th id="T_cff86_level0_col8" class="col_heading level0 col8" >Wage</th>
#       <th id="T_cff86_level0_col9" class="col_heading level0 col9" >Preferred Foot</th>
#       <th id="T_cff86_level0_col10" class="col_heading level0 col10" >International Reputation</th>
#       <th id="T_cff86_level0_col11" class="col_heading level0 col11" >Skill Moves</th>
#       <th id="T_cff86_level0_col12" class="col_heading level0 col12" >Position</th>
#       <th id="T_cff86_level0_col13" class="col_heading level0 col13" >Joined</th>
#       <th id="T_cff86_level0_col14" class="col_heading level0 col14" >Contract Valid Until</th>
#       <th id="T_cff86_level0_col15" class="col_heading level0 col15" >Height</th>
#       <th id="T_cff86_level0_col16" class="col_heading level0 col16" >Weight</th>
#       <th id="T_cff86_level0_col17" class="col_heading level0 col17" >Release Clause</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cff86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cff86_row0_col0" class="data row0 col0" >158023</td>
#       <td id="T_cff86_row0_col1" class="data row0 col1" >L. Messi</td>
#       <td id="T_cff86_row0_col2" class="data row0 col2" >31</td>
#       <td id="T_cff86_row0_col3" class="data row0 col3" >Argentina</td>
#       <td id="T_cff86_row0_col4" class="data row0 col4" >94</td>
#       <td id="T_cff86_row0_col5" class="data row0 col5" >94</td>
#       <td id="T_cff86_row0_col6" class="data row0 col6" >FC Barcelona</td>
#       <td id="T_cff86_row0_col7" class="data row0 col7" >110500.000000</td>
#       <td id="T_cff86_row0_col8" class="data row0 col8" >565.000000</td>
#       <td id="T_cff86_row0_col9" class="data row0 col9" >Left</td>
#       <td id="T_cff86_row0_col10" class="data row0 col10" >5.000000</td>
#       <td id="T_cff86_row0_col11" class="data row0 col11" >4.000000</td>
#       <td id="T_cff86_row0_col12" class="data row0 col12" >RF</td>
#       <td id="T_cff86_row0_col13" class="data row0 col13" >2004</td>
#       <td id="T_cff86_row0_col14" class="data row0 col14" >2021-01-01</td>
#       <td id="T_cff86_row0_col15" class="data row0 col15" >5.583333</td>
#       <td id="T_cff86_row0_col16" class="data row0 col16" >159.000000</td>
#       <td id="T_cff86_row0_col17" class="data row0 col17" >226500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cff86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cff86_row1_col0" class="data row1 col0" >20801</td>
#       <td id="T_cff86_row1_col1" class="data row1 col1" >Cristiano Ronaldo</td>
#       <td id="T_cff86_row1_col2" class="data row1 col2" >33</td>
#       <td id="T_cff86_row1_col3" class="data row1 col3" >Portugal</td>
#       <td id="T_cff86_row1_col4" class="data row1 col4" >94</td>
#       <td id="T_cff86_row1_col5" class="data row1 col5" >94</td>
#       <td id="T_cff86_row1_col6" class="data row1 col6" >Juventus</td>
#       <td id="T_cff86_row1_col7" class="data row1 col7" >77000.000000</td>
#       <td id="T_cff86_row1_col8" class="data row1 col8" >405.000000</td>
#       <td id="T_cff86_row1_col9" class="data row1 col9" >Right</td>
#       <td id="T_cff86_row1_col10" class="data row1 col10" >5.000000</td>
#       <td id="T_cff86_row1_col11" class="data row1 col11" >5.000000</td>
#       <td id="T_cff86_row1_col12" class="data row1 col12" >ST</td>
#       <td id="T_cff86_row1_col13" class="data row1 col13" >2018</td>
#       <td id="T_cff86_row1_col14" class="data row1 col14" >2022-01-01</td>
#       <td id="T_cff86_row1_col15" class="data row1 col15" >6.166667</td>
#       <td id="T_cff86_row1_col16" class="data row1 col16" >183.000000</td>
#       <td id="T_cff86_row1_col17" class="data row1 col17" >127100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cff86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cff86_row2_col0" class="data row2 col0" >190871</td>
#       <td id="T_cff86_row2_col1" class="data row2 col1" >Neymar Jr</td>
#       <td id="T_cff86_row2_col2" class="data row2 col2" >26</td>
#       <td id="T_cff86_row2_col3" class="data row2 col3" >Brazil</td>
#       <td id="T_cff86_row2_col4" class="data row2 col4" >92</td>
#       <td id="T_cff86_row2_col5" class="data row2 col5" >93</td>
#       <td id="T_cff86_row2_col6" class="data row2 col6" >Paris Saint-Germain</td>
#       <td id="T_cff86_row2_col7" class="data row2 col7" >118500.000000</td>
#       <td id="T_cff86_row2_col8" class="data row2 col8" >290.000000</td>
#       <td id="T_cff86_row2_col9" class="data row2 col9" >Right</td>
#       <td id="T_cff86_row2_col10" class="data row2 col10" >5.000000</td>
#       <td id="T_cff86_row2_col11" class="data row2 col11" >5.000000</td>
#       <td id="T_cff86_row2_col12" class="data row2 col12" >LW</td>
#       <td id="T_cff86_row2_col13" class="data row2 col13" >2017</td>
#       <td id="T_cff86_row2_col14" class="data row2 col14" >2022-01-01</td>
#       <td id="T_cff86_row2_col15" class="data row2 col15" >5.750000</td>
#       <td id="T_cff86_row2_col16" class="data row2 col16" >150.000000</td>
#       <td id="T_cff86_row2_col17" class="data row2 col17" >228100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cff86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cff86_row3_col0" class="data row3 col0" >193080</td>
#       <td id="T_cff86_row3_col1" class="data row3 col1" >De Gea</td>
#       <td id="T_cff86_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_cff86_row3_col3" class="data row3 col3" >Spain</td>
#       <td id="T_cff86_row3_col4" class="data row3 col4" >91</td>
#       <td id="T_cff86_row3_col5" class="data row3 col5" >93</td>
#       <td id="T_cff86_row3_col6" class="data row3 col6" >Manchester United</td>
#       <td id="T_cff86_row3_col7" class="data row3 col7" >72000.000000</td>
#       <td id="T_cff86_row3_col8" class="data row3 col8" >260.000000</td>
#       <td id="T_cff86_row3_col9" class="data row3 col9" >Right</td>
#       <td id="T_cff86_row3_col10" class="data row3 col10" >4.000000</td>
#       <td id="T_cff86_row3_col11" class="data row3 col11" >1.000000</td>
#       <td id="T_cff86_row3_col12" class="data row3 col12" >GK</td>
#       <td id="T_cff86_row3_col13" class="data row3 col13" >2011</td>
#       <td id="T_cff86_row3_col14" class="data row3 col14" >2020-01-01</td>
#       <td id="T_cff86_row3_col15" class="data row3 col15" >6.333333</td>
#       <td id="T_cff86_row3_col16" class="data row3 col16" >168.000000</td>
#       <td id="T_cff86_row3_col17" class="data row3 col17" >138600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cff86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cff86_row4_col0" class="data row4 col0" >192985</td>
#       <td id="T_cff86_row4_col1" class="data row4 col1" >K. De Bruyne</td>
#       <td id="T_cff86_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_cff86_row4_col3" class="data row4 col3" >Belgium</td>
#       <td id="T_cff86_row4_col4" class=

# %%
def highlight_max(s):
    is_max = s == s.max() # checa esse booleano s == s.max(), e depois guarda em is_max
    return ['background-color: yellow' if v else '' for v in is_max]

fifa19.head(10).style.apply(highlight_max, subset=['Age', 'Overall', 'Potential'])
# Out:
# <style type="text/css">
# #T_a3b05_row0_col4, #T_a3b05_row0_col5, #T_a3b05_row1_col2, #T_a3b05_row1_col4, #T_a3b05_row1_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a3b05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3b05_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_a3b05_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a3b05_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_a3b05_level0_col3" class="col_heading level0 col3" >Nationality</th>
#       <th id="T_a3b05_level0_col4" class="col_heading level0 col4" >Overall</th>
#       <th id="T_a3b05_level0_col5" class="col_heading level0 col5" >Potential</th>
#       <th id="T_a3b05_level0_col6" class="col_heading level0 col6" >Club</th>
#       <th id="T_a3b05_level0_col7" class="col_heading level0 col7" >Value</th>
#       <th id="T_a3b05_level0_col8" class="col_heading level0 col8" >Wage</th>
#       <th id="T_a3b05_level0_col9" class="col_heading level0 col9" >Preferred Foot</th>
#       <th id="T_a3b05_level0_col10" class="col_heading level0 col10" >International Reputation</th>
#       <th id="T_a3b05_level0_col11" class="col_heading level0 col11" >Skill Moves</th>
#       <th id="T_a3b05_level0_col12" class="col_heading level0 col12" >Position</th>
#       <th id="T_a3b05_level0_col13" class="col_heading level0 col13" >Joined</th>
#       <th id="T_a3b05_level0_col14" class="col_heading level0 col14" >Contract Valid Until</th>
#       <th id="T_a3b05_level0_col15" class="col_heading level0 col15" >Height</th>
#       <th id="T_a3b05_level0_col16" class="col_heading level0 col16" >Weight</th>
#       <th id="T_a3b05_level0_col17" class="col_heading level0 col17" >Release Clause</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3b05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3b05_row0_col0" class="data row0 col0" >158023</td>
#       <td id="T_a3b05_row0_col1" class="data row0 col1" >L. Messi</td>
#       <td id="T_a3b05_row0_col2" class="data row0 col2" >31</td>
#       <td id="T_a3b05_row0_col3" class="data row0 col3" >Argentina</td>
#       <td id="T_a3b05_row0_col4" class="data row0 col4" >94</td>
#       <td id="T_a3b05_row0_col5" class="data row0 col5" >94</td>
#       <td id="T_a3b05_row0_col6" class="data row0 col6" >FC Barcelona</td>
#       <td id="T_a3b05_row0_col7" class="data row0 col7" >110500.000000</td>
#       <td id="T_a3b05_row0_col8" class="data row0 col8" >565.000000</td>
#       <td id="T_a3b05_row0_col9" class="data row0 col9" >Left</td>
#       <td id="T_a3b05_row0_col10" class="data row0 col10" >5.000000</td>
#       <td id="T_a3b05_row0_col11" class="data row0 col11" >4.000000</td>
#       <td id="T_a3b05_row0_col12" class="data row0 col12" >RF</td>
#       <td id="T_a3b05_row0_col13" class="data row0 col13" >2004</td>
#       <td id="T_a3b05_row0_col14" class="data row0 col14" >2021-01-01</td>
#       <td id="T_a3b05_row0_col15" class="data row0 col15" >5.583333</td>
#       <td id="T_a3b05_row0_col16" class="data row0 col16" >159.000000</td>
#       <td id="T_a3b05_row0_col17" class="data row0 col17" >226500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3b05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3b05_row1_col0" class="data row1 col0" >20801</td>
#       <td id="T_a3b05_row1_col1" class="data row1 col1" >Cristiano Ronaldo</td>
#       <td id="T_a3b05_row1_col2" class="data row1 col2" >33</td>
#       <td id="T_a3b05_row1_col3" class="data row1 col3" >Portugal</td>
#       <td id="T_a3b05_row1_col4" class="data row1 col4" >94</td>
#       <td id="T_a3b05_row1_col5" class="data row1 col5" >94</td>
#       <td id="T_a3b05_row1_col6" class="data row1 col6" >Juventus</td>
#       <td id="T_a3b05_row1_col7" class="data row1 col7" >77000.000000</td>
#       <td id="T_a3b05_row1_col8" class="data row1 col8" >405.000000</td>
#       <td id="T_a3b05_row1_col9" class="data row1 col9" >Right</td>
#       <td id="T_a3b05_row1_col10" class="data row1 col10" >5.000000</td>
#       <td id="T_a3b05_row1_col11" class="data row1 col11" >5.000000</td>
#       <td id="T_a3b05_row1_col12" class="data row1 col12" >ST</td>
#       <td id="T_a3b05_row1_col13" class="data row1 col13" >2018</td>
#       <td id="T_a3b05_row1_col14" class="data row1 col14" >2022-01-01</td>
#       <td id="T_a3b05_row1_col15" class="data row1 col15" >6.166667</td>
#       <td id="T_a3b05_row1_col16" class="data row1 col16" >183.000000</td>
#       <td id="T_a3b05_row1_col17" class="data row1 col17" >127100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3b05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3b05_row2_col0" class="data row2 col0" >190871</td>
#       <td id="T_a3b05_row2_col1" class="data row2 col1" >Neymar Jr</td>
#       <td id="T_a3b05_row2_col2" class="data row2 col2" >26</td>
#       <td id="T_a3b05_row2_col3" class="data row2 col3" >Brazil</td>
#       <td id="T_a3b05_row2_col4" class="data row2 col4" >92</td>
#       <td id="T_a3b05_row2_col5" class="data row2 col5" >93</td>
#       <td id="T_a3b05_row2_col6" class="data row2 col6" >Paris Saint-Germain</td>
#       <td id="T_a3b05_row2_col7" class="data row2 col7" >118500.000000</td>
#       <td id="T_a3b05_row2_col8" class="data row2 col8" >290.000000</td>
#       <td id="T_a3b05_row2_col9" class="data row2 col9" >Right</td>
#       <td id="T_a3b05_row2_col10" class="data row2 col10" >5.000000</td>
#       <td id="T_a3b05_row2_col11" class="data row2 col11" >5.000000</td>
#       <td id="T_a3b05_row2_col12" class="data row2 col12" >LW</td>
#       <td id="T_a3b05_row2_col13" class="data row2 col13" >2017</td>
#       <td id="T_a3b05_row2_col14" class="data row2 col14" >2022-01-01</td>
#       <td id="T_a3b05_row2_col15" class="data row2 col15" >5.750000</td>
#       <td id="T_a3b05_row2_col16" class="data row2 col16" >150.000000</td>
#       <td id="T_a3b05_row2_col17" class="data row2 col17" >228100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3b05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3b05_row3_col0" class="data row3 col0" >193080</td>
#       <td id="T_a3b05_row3_col1" class="data row3 col1" >De Gea</td>
#       <td id="T_a3b05_row3_col2" class="data row3 col2" >27</td>
#       <td id="T_a3b05_row3_col3" class="data row3 col3" >Spain</td>
#       <td id="T_a3b05_row3_col4" class="data row3 col4" >91</td>
#       <td id="T_a3b05_row3_col5" class="data row3 col5" >93</td>
#       <td id="T_a3b05_row3_col6" class="data row3 col6" >Manchester United</td>
#       <td id="T_a3b05_row3_col7" class="data row3 col7" >72000.000000</td>
#       <td id="T_a3b05_row3_col8" class="data row3 col8" >260.000000</td>
#       <td id="T_a3b05_row3_col9" class="data row3 col9" >Right</td>
#       <td id="T_a3b05_row3_col10" class="data row3 col10" >4.000000</td>
#       <td id="T_a3b05_row3_col11" class="data row3 col11" >1.000000</td>
#       <td id="T_a3b05_row3_col12" class="data row3 col12" >GK</td>
#       <td id="T_a3b05_row3_col13" class="data row3 col13" >2011</td>
#       <td id="T_a3b05_row3_col14" class="data row3 col14" >2020-01-01</td>
#       <td id="T_a3b05_row3_col15" class="data row3 col15" >6.333333</td>
#       <td id="T_a3b05_row3_col16" class="data row3 col16" >168.000000</td>
#       <td id="T_a3b05_row3_col17" class="data row3 col17" >138600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3b05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3b05_row4_col0" class="data row4 col0" >192985</td>
#       <td id="T_a3b05_row4_col1" class="data row4 col1" >K. De Bruyne</td>
#       <td id="T_a3b05_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_a3b05_row4_col3" class="data row4 col3" >Belgium</td>
#       <td id="T_a3b05_row4_col4" class="data row4 col4" >91</td>
#       <td id="T_a3b05_row4_col5" class="data row4 col5" >92</td>
#       <td id="T_a3b05_row4_col6" class="data row4 col6" >Manchester City</td>
#       <td id="T_a3b05_row4_col7" class="data row4 col7" >102000.000000</td>
#       <td id="T_a3b05_row4_col8" class="data row4 col8" >355

# %%
fifa19[['Overall', 'Potential']].head(10).style.\
applymap(low_values_red).\
apply(highlight_max)
# Out:
# <style type="text/css">
# #T_8732b_row0_col0, #T_8732b_row0_col1, #T_8732b_row1_col0, #T_8732b_row1_col1 {
#   color: black;
#   background-color: yellow;
# }
# #T_8732b_row2_col0, #T_8732b_row2_col1, #T_8732b_row3_col1, #T_8732b_row4_col1, #T_8732b_row9_col1 {
#   color: black;
# }
# #T_8732b_row3_col0, #T_8732b_row4_col0, #T_8732b_row5_col0, #T_8732b_row5_col1, #T_8732b_row6_col0, #T_8732b_row6_col1, #T_8732b_row7_col0, #T_8732b_row7_col1, #T_8732b_row8_col0, #T_8732b_row8_col1, #T_8732b_row9_col0 {
#   color: red;
# }
# </style>
# <table id="T_8732b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8732b_level0_col0" class="col_heading level0 col0" >Overall</th>
#       <th id="T_8732b_level0_col1" class="col_heading level0 col1" >Potential</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8732b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8732b_row0_col0" class="data row0 col0" >94</td>
#       <td id="T_8732b_row0_col1" class="data row0 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8732b_row1_col0" class="data row1 col0" >94</td>
#       <td id="T_8732b_row1_col1" class="data row1 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8732b_row2_col0" class="data row2 col0" >92</td>
#       <td id="T_8732b_row2_col1" class="data row2 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8732b_row3_col0" class="data row3 col0" >91</td>
#       <td id="T_8732b_row3_col1" class="data row3 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8732b_row4_col0" class="data row4 col0" >91</td>
#       <td id="T_8732b_row4_col1" class="data row4 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8732b_row5_col0" class="data row5 col0" >91</td>
#       <td id="T_8732b_row5_col1" class="data row5 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8732b_row6_col0" class="data row6 col0" >91</td>
#       <td id="T_8732b_row6_col1" class="data row6 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8732b_row7_col0" class="data row7 col0" >91</td>
#       <td id="T_8732b_row7_col1" class="data row7 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8732b_row8_col0" class="data row8 col0" >91</td>
#       <td id="T_8732b_row8_col1" class="data row8 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_8732b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8732b_row9_col0" class="data row9 col0" >90</td>
#       <td id="T_8732b_row9_col1" class="data row9 col1" >93</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Mais sobre formatação em: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html

# %% [markdown]
# ### 3. Filtros e Seleções

# %%
fifa19.head(5)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
fifa19.loc[1]
# Out:
# ID                                      20801
# Name                        Cristiano Ronaldo
# Age                                        33
# Nationality                          Portugal
# Overall                                    94
# Potential                                  94
# Club                                 Juventus
# Value                                 77000.0
# Wage                                    405.0
# Preferred Foot                          Right
# International Reputation                  5.0
# Skill Moves                               5.0
# Position                                   ST
# Joined                                   2018
# Contract Valid Until               2022-01-01
# Height                               6.166667
# Weight                                  183.0
# Release Clause                       127100.0
# Name: 1, dtype: object

# %%
fifa19.loc[0:5]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
# 5              Chelsea   93000.0  340.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
# 5                       4.0          4.0       LF    2012
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0
# 5           2020-01-01  5.666667   163.0        172100.0

# %%
fifa19[0:5]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
fifa19.loc[0:5, 'Age']
# Out:
# 0    31
# 1    33
# 2    26
# 3    27
# 4    27
# 5    27
# Name: Age, dtype: int64

# %%
fifa19.iloc[0:5, 1:4]
# Out:
#                 Name  Age Nationality
# 0           L. Messi   31   Argentina
# 1  Cristiano Ronaldo   33    Portugal
# 2          Neymar Jr   26      Brazil
# 3             De Gea   27       Spain
# 4       K. De Bruyne   27     Belgium

# %%
fifa19[0:10]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
# 9  200389           J. Oblak   25    Slovenia       90         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
# 5              Chelsea   93000.0  340.0          Right
# 6          Real Madrid   67000.0  420.0          Right
# 7         FC Barcelona   80000.0  455.0          Right
# 8          Real Madrid   51000.0  380.0          Right
# 9      Atlético Madrid   68000.0   94.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
# 5                       4.0          4.0       LF    2012
# 6                       4.0          4.0      RCM    2012
# 7                       5.0          3.0       RS    2014
# 8                       4.0          3.0      RCB    2005
# 9                       3.0          1.0       GK    2014
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0
# 5           2020-01-01  5.666667   163.0        172100.0
# 6           2020-01-01  5.666667   146.0        137400.0
# 7           2021-01-01  6.000000   190.0        164000.0
# 8           2020-01-01  6.000000   181.0        104600.0
# 9           2021-01-01  6.166667   192.0        144500.0

# %%
 fifa19.loc[(fifa19['Age'] > 30) & (fifa19['Overall'] >= 90)]
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 12  182493           D. Godín   32     Uruguay       90         90
# 13  168542        David Silva   32       Spain       90         90
#
#                Club     Value   Wage Preferred Foot  International Reputation  \
# 0      FC Barcelona  110500.0  565.0           Left                       5.0
# 1          Juventus   77000.0  405.0          Right                       5.0
# 6       Real Madrid   67000.0  420.0          Right                       4.0
# 7      FC Barcelona   80000.0  455.0          Right                       5.0
# 8       Real Madrid   51000.0  380.0          Right                       4.0
# 12  Atlético Madrid   44000.0  125.0          Right                       3.0
# 13  Manchester City   60000.0  285.0           Left                       4.0
#
#     Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0           4.0       RF    2004           2021-01-01  5.583333   159.0
# 1           5.0       ST    2018           2022-01-01  6.166667   183.0
# 6           4.0      RCM    2012           2020-01-01  5.666667   146.0
# 7           3.0       RS    2014           2021-01-01  6.000000   190.0
# 8           3.0      RCB    2005           2020-01-01  6.000000   181.0
# 12          2.0       CB    2010           2019-01-01  6.166667   172.0
# 13          4.0      LCM    2010           2020-01-01  5.666667   148.0
#
#     Release Clause
# 0         226500.0
# 1         127100.0
# 6         137400.0
# 7         164000.0
# 8         104600.0
# 12         90200.0
# 13        111000.0

# %%
tiozoes_do_fifa = fifa19.query("Age > 30")
tiozoes_do_fifa.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
# 6   Real Madrid   67000.0  420.0          Right                       4.0
# 7  FC Barcelona   80000.0  455.0          Right                       5.0
# 8   Real Madrid   51000.0  380.0          Right                       4.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
# 6          4.0      RCM    2012           2020-01-01  5.666667   146.0
# 7          3.0       RS    2014           2021-01-01  6.000000   190.0
# 8          3.0      RCB    2005           2020-01-01  6.000000   181.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0
# 6        137400.0
# 7        164000.0
# 8        104600.0

# %%
fifa19[fifa19['Age']>30]
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 0      158023           L. Messi   31   Argentina       94         94
# 1       20801  Cristiano Ronaldo   33    Portugal       94         94
# 6      177003          L. Modrić   32     Croatia       91         91
# 7      176580          L. Suárez   31     Uruguay       91         91
# 8      155862       Sergio Ramos   32       Spain       91         91
# ...       ...                ...  ...         ...      ...        ...
# 17842  182461          Zhou Ting   39    China PR       52         52
# 17866  232676           N. Hatta   32       Japan       52         52
# 18043  237917          A. Suzuki   31       Japan       50         50
# 18171  237746        Y. Uchimura   33       Japan       48         48
# 18183   53748      K. Pilkington   44     England       48         48
#
#                              Club     Value   Wage Preferred Foot  \
# 0                    FC Barcelona  110500.0  565.0           Left
# 1                        Juventus   77000.0  405.0          Right
# 6                     Real Madrid   67000.0  420.0          Right
# 7                    FC Barcelona   80000.0  455.0          Right
# 8                     Real Madrid   51000.0  380.0          Right
# ...                           ...       ...    ...            ...
# 17842            Dalian YiFang FC      10.0    1.0          Right
# 17866                Júbilo Iwata      30.0    1.0          Right
# 18043         Yokohama F. Marinos      20.0    1.0          Right
# 18171  Hokkaido Consadole Sapporo      20.0    1.0          Right
# 18183            Cambridge United       NaN    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 6                           4.0          4.0      RCM    2012
# 7                           5.0          3.0       RS    2014
# 8                           4.0          3.0      RCB    2005
# ...                         ...          ...      ...     ...
# 17842                       1.0          2.0       CM    2017
# 17866                       1.0          1.0       GK    2005
# 18043                       1.0          1.0       GK    2017
# 18171                       1.0          2.0      CAM    2010
# 18183                       1.0          1.0       GK    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0   226500.000000
# 1               2022-01-01  6.166667   183.0   127100.000000
# 6               2020-01-01  5.666667   146.0   137400.000000
# 7               2021-01-01  6.000000   190.0   164000.000000
# 8               2020-01-01  6.000000   181.0   104600.000000
# ...                    ...       ...     ...             ...
# 17842           2020-01-01  6.083333   163.0       22.000000
# 17866           2021-01-01  6.083333   168.0       38.000000
# 18043           2021-01-01  6.000000   176.0       25.000000
# 18171           2021-01-01  5.750000   148.0       25.000000
# 18183           2023-01-01  6.166667   190.0     4585.060806
#
# [2582 rows x 18 columns]

# %%
fifa19[fifa19['International Reputation'] == fifa19['Skill Moves']]
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 1       20801  Cristiano Ronaldo   33    Portugal       94         94
# 2      190871          Neymar Jr   26      Brazil       92         93
# 4      192985       K. De Bruyne   27     Belgium       91         92
# 5      183277          E. Hazard   27     Belgium       91         91
# 6      177003          L. Modrić   32     Croatia       91         91
# ...       ...                ...  ...         ...      ...        ...
# 18178  243158       L. Wahlstedt   18      Sweden       48         65
# 18180  221669           M. Hurst   22    Scotland       48         58
# 18183   53748      K. Pilkington   44     England       48         48
# 18194  245862           J. Milli   18       Italy       47         65
# 18198  242844         J. Livesey   18     England       47         70
#
#                       Club     Value   Wage Preferred Foot  \
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 4          Manchester City  102000.0  355.0          Right
# 5                  Chelsea   93000.0  340.0          Right
# 6              Real Madrid   67000.0  420.0          Right
# ...                    ...       ...    ...            ...
# 18178           Dalkurd FF      50.0    1.0          Right
# 18180     St. Johnstone FC      40.0    1.0          Right
# 18183     Cambridge United       NaN    1.0          Right
# 18194                Lecce      50.0    1.0          Right
# 18198        Burton Albion      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 4                           4.0          4.0      RCM    2015
# 5                           4.0          4.0       LF    2012
# 6                           4.0          4.0      RCM    2012
# ...                         ...          ...      ...     ...
# 18178                       1.0          1.0       GK    2018
# 18180                       1.0          1.0       GK    2013
# 18183                       1.0          1.0       GK    2018
# 18194                       1.0          1.0       GK    2018
# 18198                       1.0          1.0       GK    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 1               2022-01-01  6.166667   183.0   127100.000000
# 2               2022-01-01  5.750000   150.0   228100.000000
# 4               2023-01-01  5.916667   154.0   196400.000000
# 5               2020-01-01  5.666667   163.0   172100.000000
# 6               2020-01-01  5.666667   146.0   137400.000000
# ...                    ...       ...     ...             ...
# 18178           2018-01-01  6.000000   176.0       94.000000
# 18180           2019-01-01  6.083333   172.0       78.000000
# 18183           2023-01-01  6.166667   190.0     4585.060806
# 18194           2021-01-01  6.250000   187.0      109.000000
# 18198           2021-01-01  5.916667   154.0      165.000000
#
# [2304 rows x 18 columns]

# %%
fifa19.filter(['Age', 'ID', 'Name'])
# Out:
#        Age      ID                Name
# 0       31  158023            L. Messi
# 1       33   20801   Cristiano Ronaldo
# 2       26  190871           Neymar Jr
# 3       27  193080              De Gea
# 4       27  192985        K. De Bruyne
# ...    ...     ...                 ...
# 18202   19  238813        J. Lundstram
# 18203   19  243165  N. Christoffersson
# 18204   16  241638           B. Worman
# 18205   17  246268      D. Walker-Rice
# 18206   16  246269           G. Nugent
#
# [18207 rows x 3 columns]

# %%
overall_median = fifa19['Overall'].median()
fifa19.query("Overall > @overall_median")
# Out:
#           ID               Name  Age Nationality  Overall  Potential  \
# 0     158023           L. Messi   31   Argentina       94         94
# 1      20801  Cristiano Ronaldo   33    Portugal       94         94
# 2     190871          Neymar Jr   26      Brazil       92         93
# 3     193080             De Gea   27       Spain       91         93
# 4     192985       K. De Bruyne   27     Belgium       91         92
# ...      ...                ...  ...         ...      ...        ...
# 8759  224509           U. Rivas   22      Mexico       67         73
# 8760  214014        C. Lizarazo   27    Colombia       67         67
# 8761  104702         D. Braaten   36      Norway       67         67
# 8762  229631               Lazo   22       Spain       67         75
# 8763  246015            L. Mago   23   Venezuela       67         73
#
#                      Club     Value   Wage Preferred Foot  \
# 0            FC Barcelona  110500.0  565.0           Left
# 1                Juventus   77000.0  405.0          Right
# 2     Paris Saint-Germain  118500.0  290.0          Right
# 3       Manchester United   72000.0  260.0          Right
# 4         Manchester City  102000.0  355.0          Right
# ...                   ...       ...    ...            ...
# 8759        Santos Laguna    1000.0    6.0          Right
# 8760      América de Cali     800.0    1.0           Left
# 8761             SK Brann     260.0    2.0          Right
# 8762              CD Lugo    1100.0    7.0           Left
# 8763                  NaN       NaN    0.0           Left
#
#       International Reputation  Skill Moves Position  Joined  \
# 0                          5.0          4.0       RF    2004
# 1                          5.0          5.0       ST    2018
# 2                          5.0          5.0       LW    2017
# 3                          4.0          1.0       GK    2011
# 4                          4.0          4.0      RCM    2015
# ...                        ...          ...      ...     ...
# 8759                       1.0          2.0       CM    2014
# 8760                       1.0          3.0      CAM    2018
# 8761                       1.0          3.0       RW    2016
# 8762                       1.0          3.0       LM    2016
# 8763                       1.0          2.0       LB    2016
#
#      Contract Valid Until    Height  Weight  Release Clause
# 0              2021-01-01  5.583333   159.0   226500.000000
# 1              2022-01-01  6.166667   183.0   127100.000000
# 2              2022-01-01  5.750000   150.0   228100.000000
# 3              2020-01-01  6.333333   168.0   138600.000000
# 4              2023-01-01  5.916667   154.0   196400.000000
# ...                   ...       ...     ...             ...
# 8759           2023-01-01  5.833333   157.0     2000.000000
# 8760           2019-01-01  5.583333   148.0     1100.000000
# 8761           2018-01-01  6.000000   207.0      325.000000
# 8762           2019-06-30  5.833333   152.0     4585.060806
# 8763                  NaN  6.000000   174.0     4585.060806
#
# [8764 rows x 18 columns]

# %%
df_champs = fifa19[fifa19['Nationality'].isin(['Argentina', 'Brazil', 'Germany', 'France', 'Italy', 'England'])]
df_champs.head()
# Out:
#         ID       Name  Age Nationality  Overall  Potential  \
# 0   158023   L. Messi   31   Argentina       94         94
# 2   190871  Neymar Jr   26      Brazil       92         93
# 11  182521   T. Kroos   28     Germany       90         90
# 14  215914   N. Kanté   27      France       89         90
# 15  211110  P. Dybala   24   Argentina       89         94
#
#                    Club     Value   Wage Preferred Foot  \
# 0          FC Barcelona  110500.0  565.0           Left
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 11          Real Madrid   76500.0  355.0          Right
# 14              Chelsea   63000.0  225.0          Right
# 15             Juventus   89000.0  205.0           Left
#
#     International Reputation  Skill Moves Position  Joined  \
# 0                        5.0          4.0       RF    2004
# 2                        5.0          5.0       LW    2017
# 11                       4.0          3.0      LCM    2014
# 14                       3.0          2.0      LDM    2016
# 15                       3.0          4.0       LF    2015
#
#    Contract Valid Until    Height  Weight  Release Clause
# 0            2021-01-01  5.583333   159.0        226500.0
# 2            2022-01-01  5.750000   150.0        228100.0
# 11           2022-01-01  6.000000   168.0        156800.0
# 14           2023-01-01  5.500000   159.0        121300.0
# 15           2022-01-01  5.833333   165.0        153500.0

# %%
df_no_champs = fifa19[~fifa19['Nationality'].isin(['Argentina', 'Brazil', 'Germany', 'France', 'Italy', 'England'])]
df_no_champs.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
#
#                 Club     Value   Wage Preferred Foot  \
# 1           Juventus   77000.0  405.0          Right
# 3  Manchester United   72000.0  260.0          Right
# 4    Manchester City  102000.0  355.0          Right
# 5            Chelsea   93000.0  340.0          Right
# 6        Real Madrid   67000.0  420.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 1                       5.0          5.0       ST    2018
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
# 5                       4.0          4.0       LF    2012
# 6                       4.0          4.0      RCM    2012
#
#   Contract Valid Until    Height  Weight  Release Clause
# 1           2022-01-01  6.166667   183.0        127100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0
# 5           2020-01-01  5.666667   163.0        172100.0
# 6           2020-01-01  5.666667   146.0        137400.0

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
fifa19_numerics = fifa19.select_dtypes(include = numerics)
fifa19_numerics.head()
# Out:
#        ID  Age  Overall  Potential     Value   Wage  International Reputation  \
# 0  158023   31       94         94  110500.0  565.0                       5.0
# 1   20801   33       94         94   77000.0  405.0                       5.0
# 2  190871   26       92         93  118500.0  290.0                       5.0
# 3  193080   27       91         93   72000.0  260.0                       4.0
# 4  192985   27       91         92  102000.0  355.0                       4.0
#
#    Skill Moves  Joined    Height  Weight  Release Clause
# 0          4.0    2004  5.583333   159.0        226500.0
# 1          5.0    2018  6.166667   183.0        127100.0
# 2          5.0    2017  5.750000   150.0        228100.0
# 3          1.0    2011  6.333333   168.0        138600.0
# 4          4.0    2015  5.916667   154.0        196400.0

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
fifa19_non_numerics = fifa19.select_dtypes(exclude = numerics)
fifa19_non_numerics.head()
# Out:
#                 Name Nationality                 Club Preferred Foot Position  \
# 0           L. Messi   Argentina         FC Barcelona           Left       RF
# 1  Cristiano Ronaldo    Portugal             Juventus          Right       ST
# 2          Neymar Jr      Brazil  Paris Saint-Germain          Right       LW
# 3             De Gea       Spain    Manchester United          Right       GK
# 4       K. De Bruyne     Belgium      Manchester City          Right      RCM
#
#   Contract Valid Until
# 0           2021-01-01
# 1           2022-01-01
# 2           2022-01-01
# 3           2020-01-01
# 4           2023-01-01

# %%
fifa19.sort_values(by = 'Overall', ascending= False).head(10)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 12  182493           D. Godín   32     Uruguay       90         90
#
#                    Club     Value   Wage Preferred Foot  \
# 0          FC Barcelona  110500.0  565.0           Left
# 1              Juventus   77000.0  405.0          Right
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 3     Manchester United   72000.0  260.0          Right
# 4       Manchester City  102000.0  355.0          Right
# 5               Chelsea   93000.0  340.0          Right
# 6           Real Madrid   67000.0  420.0          Right
# 7          FC Barcelona   80000.0  455.0          Right
# 8           Real Madrid   51000.0  380.0          Right
# 12      Atlético Madrid   44000.0  125.0          Right
#
#     International Reputation  Skill Moves Position  Joined  \
# 0                        5.0          4.0       RF    2004
# 1                        5.0          5.0       ST    2018
# 2                        5.0          5.0       LW    2017
# 3                        4.0          1.0       GK    2011
# 4                        4.0          4.0      RCM    2015
# 5                        4.0          4.0       LF    2012
# 6                        4.0          4.0      RCM    2012
# 7                        5.0          3.0       RS    2014
# 8                        4.0          3.0      RCB    2005
# 12                       3.0          2.0       CB    2010
#
#    Contract Valid Until    Height  Weight  Release Clause
# 0            2021-01-01  5.583333   159.0        226500.0
# 1            2022-01-01  6.166667   183.0        127100.0
# 2            2022-01-01  5.750000   150.0        228100.0
# 3            2020-01-01  6.333333   168.0        138600.0
# 4            2023-01-01  5.916667   154.0        196400.0
# 5            2020-01-01  5.666667   163.0        172100.0
# 6            2020-01-01  5.666667   146.0        137400.0
# 7            2021-01-01  6.000000   190.0        164000.0
# 8            2020-01-01  6.000000   181.0        104600.0
# 12           2019-01-01  6.166667   172.0         90200.0

# %%
fifa19.drop_duplicates()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# ...                    ...       ...     ...             ...
# 18202           2019-01-01  5.750000   134.0           143.0
# 18203           2020-01-01  6.250000   170.0           113.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [18207 rows x 18 columns]

# %% [markdown]
# ### Estatística Descritiva

# %%
fifa19.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# std       21.999290                  0.394031      0.756164      2.018194
# min        0.000000                  1.000000      1.000000   1991.000000
# 25%        1.000000                  1.000000      2.000000   2016.000000
# 50%        3.000000                  1.000000      2.000000   2017.000000
# 75%        9.000000                  1.000000      3.000000   2018.000000
# max      565.000000                  5.000000      5.000000   2018.000000
#
#              Height        Weight  Release Clause
# count  18207.000000  18207.000000    18207.000000
# mean       5.946771    165.979129     4585.060971
# std        0.220514     15.572775    10630.414430
# min        5.083333    110.000000       13.000000
# 25%        5.750000    154.000000      570.000000
# 50%        5.916667    165.000000     1300.000000
# 75%        6.083333    176.000000     4585.060806
# max        6.750000    243.000000   228100.000000

# %%
fifa19['Age'].describe(percentiles=[0.1, 0.2, 0.8, 0.99])
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 10%         19.000000
# 20%         21.000000
# 50%         25.000000
# 80%         29.000000
# 99%         36.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
fifa19.agg({'Age': ['min', 'max', 'skew', 'median'],
            'Overall':['mean', 'min']})
# Out:
#               Age    Overall
# min     16.000000  46.000000
# max     45.000000        NaN
# skew     0.391764        NaN
# median  25.000000        NaN
# mean          NaN  66.238699

# %%
df_champs.groupby(fifa19['Nationality'])[['Age', 'Overall']].mean().sort_values(by = 'Overall', ascending= False)
# Out:
#                    Age    Overall
# Nationality
# Brazil       27.625151  71.251511
# Argentina    26.205977  68.572038
# Italy        25.928775  68.158120
# France       24.615974  67.798687
# Germany      24.338063  66.086811
# England      24.030084  63.429603

# %%
import numpy as np 

pd.pivot_table(df_champs, index = ['Nationality'], values=fifa19_numerics, aggfunc=np.mean)
# Out:
#                    Age    Height             ID  International Reputation  \
# Nationality
# Argentina    26.205977  5.868940  214452.561366                  1.133547
# Brazil       27.625151  5.937396  218810.801693                  1.163636
# England      24.030084  5.957572  207327.731649                  1.065178
# France       24.615974  5.956244  214077.617068                  1.206367
# Germany      24.338063  6.026787  217681.117696                  1.138912
# Italy        25.928775  5.989326  206580.970085                  1.207439
#
#                   Joined    Overall  Potential  Release Clause  Skill Moves  \
# Nationality
# Argentina    2016.462113  68.572038  73.210245     5342.674839     2.454060
# Brazil       2017.178960  71.251511  73.351874     8695.941199     2.633939
# England      2016.365223  63.429603  70.037304     3244.199982     2.253470
# France       2016.640044  67.798687  73.447484     7206.857450     2.400659
# Germany      2016.489983  66.086811  71.699499     4578.126760     2.279498
# Italy        2016.316239  68.158120  72.690883     5379.739999     2.396280
#
#                    Value       Wage      Weight
# Nationality
# Argentina    3080.299145  11.502668  165.665933
# Brazil       4608.202179  17.778718  167.576733
# England      1500.551205   9.943442  164.124486
# France       3683.849945  14.053611  166.600588
# Germany      2529.307179   9.639399  172.301283
# Italy        3047.571225  13.478632  167.474270

# %%
pd.pivot_table(df_champs, index = ['Nationality'], values = ['Age', 'Overall', 'Potential'], aggfunc=np.mean)
# Out:
#                    Age    Overall  Potential
# Nationality
# Argentina    26.205977  68.572038  73.210245
# Brazil       27.625151  71.251511  73.351874
# England      24.030084  63.429603  70.037304
# France       24.615974  67.798687  73.447484
# Germany      24.338063  66.086811  71.699499
# Italy        25.928775  68.158120  72.690883

# %%
fifa19.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
pd.pivot_table(df_champs, index = ['Nationality', 'Position'], columns = ['Club'], values = ['Age', 'Overall', 'Value'], aggfunc=np.mean)
# Out:
#                                       Age                        \
# Club                  SSV Jahn Regensburg 1. FC Heidenheim 1846
# Nationality Position
# Argentina   CAM                       NaN                   NaN
#             CB                        NaN                   NaN
#             CDM                       NaN                   NaN
#             CF                        NaN                   NaN
#             CM                        NaN                   NaN
# ...                                   ...                   ...
# Italy       RM                        NaN                   NaN
#             RS                        NaN                   NaN
#             RW                        NaN                   NaN
#             RWB                       NaN                   NaN
#             ST                        NaN                   NaN
#
#                                                                       \
# Club                 1. FC Kaiserslautern 1. FC Köln 1. FC Magdeburg
# Nationality Position
# Argentina   CAM                       NaN        NaN             NaN
#             CB                        NaN        NaN             NaN
#             CDM                       NaN        NaN             NaN
#             CF                        NaN        NaN             NaN
#             CM                        NaN        NaN             NaN
# ...                                   ...        ...             ...
# Italy       RM                        NaN        NaN             NaN
#             RS                        NaN        NaN             NaN
#             RW                        NaN        NaN             NaN
#             RWB                       NaN        NaN             NaN
#             ST                        NaN        NaN             NaN
#
#                                                                         \
# Club                 1. FC Nürnberg 1. FC Union Berlin 1. FSV Mainz 05
# Nationality Position
# Argentina   CAM                 NaN                NaN             NaN
#             CB                  NaN                NaN             NaN
#             CDM                 NaN                NaN             NaN
#             CF                  NaN                NaN             NaN
#             CM                  NaN                NaN             NaN
# ...                             ...                ...             ...
# Italy       RM                  NaN                NaN             NaN
#             RS                  NaN                NaN             NaN
#             RW                  NaN                NaN             NaN
#             RWB                 NaN                NaN             NaN
#             ST                  NaN                NaN             NaN
#
#                                             ...          Value  \
# Club                 AC Ajaccio AC Horsens  ... Wolfsberger AC
# Nationality Position                        ...
# Argentina   CAM             NaN        NaN  ...            NaN
#             CB              NaN        NaN  ...            NaN
#             CDM             NaN        NaN  ...            NaN
#             CF              NaN        NaN  ...            NaN
#             CM              NaN        NaN  ...            NaN
# ...                         ...        ...  ...            ...
# Italy       RM              NaN        NaN  ...            NaN
#             RS              NaN        NaN  ...            NaN
#             RW              NaN        NaN  ...            NaN
#             RWB             NaN        NaN  ...            NaN
#             ST              NaN        NaN  ...            NaN
#
#                                                                 \
# Club                 Wolverhampton Wanderers Wycombe Wanderers
# Nationality Position
# Argentina   CAM                          NaN               NaN
#             CB                           NaN               NaN
#             CDM                          NaN               NaN
#             CF                           NaN               NaN
#             CM                           NaN               NaN
# ...                                      ...               ...
# Italy       RM                           NaN               NaN
#             RS                           NaN               NaN
#             RW                           NaN               NaN
#             RWB                          NaN               NaN
#             ST                           NaN               NaN
#
#                                                                        \
# Club                 Yeni Malatyaspor Yeovil Town Yokohama F. Marinos
# Nationality Position
# Argentina   CAM                   NaN         NaN                 NaN
#             CB                    NaN         NaN                 NaN
#             CDM                   NaN         NaN                 NaN
#             CF                    NaN         NaN                 NaN
#             CM                    NaN         NaN                 NaN
# ...                               ...         ...                 ...
# Italy       RM                    NaN         NaN                 NaN
#             RS                    NaN         NaN                 NaN
#             RW                    NaN         NaN                 NaN
#             RWB                   NaN         NaN                 NaN
#             ST                    NaN         NaN                 NaN
#
#                                                                    \
# Club                 Zagłębie Sosnowiec Çaykur Rizespor Örebro SK
# Nationality Position
# Argentina   CAM                     NaN             NaN       NaN
#             CB                      NaN             NaN       NaN
#             CDM                     NaN             NaN       NaN
#             CF                      NaN             NaN       NaN
#             CM                      NaN             NaN       NaN
# ...                                 ...             ...       ...
# Italy       RM                      NaN             NaN       NaN
#             RS                      NaN             NaN       NaN
#             RW                      NaN             NaN       NaN
#             RWB                     NaN             NaN       NaN
#             ST                      NaN             NaN       NaN
#
#
# Club                 Östersunds FK
# Nationality Position
# Argentina   CAM                NaN
#             CB                 NaN
#             CDM                NaN
#             CF                 NaN
#             CM                 NaN
# ...                            ...
# Italy       RM                 NaN
#             RS                 NaN
#             RW                 NaN
#             RWB                NaN
#             ST                 NaN
#
# [145 rows x 1737 columns]

# %%
df_champs.Nationality.value_counts()
# Out:
# Nationality
# England      1662
# Germany      1198
# Argentina     937
# France        914
# Brazil        827
# Italy         702
# Name: count, dtype: int64

# %%
df_champs.Nationality.value_counts(normalize=True)
# Out:
# Nationality
# England      0.266346
# Germany      0.191987
# Argentina    0.150160
# France       0.146474
# Brazil       0.132532
# Italy        0.112500
# Name: proportion, dtype: float64

# %%
df_champs.groupby('Club')['Nationality'].value_counts()
# Out:
# Club                   Nationality
#  SSV Jahn Regensburg   Germany        22
# 1. FC Heidenheim 1846  Germany        27
# 1. FC Kaiserslautern   Germany        21
# 1. FC Köln             Germany        20
#                        France          2
#                                       ..
# Çaykur Rizespor        Italy           1
#                        France          1
#                        Brazil          1
# Örebro SK              Brazil          1
# Östersunds FK          England         5
# Name: count, Length: 988, dtype: int64

# %%
df_champs.groupby('Nationality')['Position'].value_counts()
# Out:
# Nationality  Position
# Argentina    ST          125
#              CB           99
#              GK           97
#              LM           64
#              RM           62
#                         ...
# Italy        RDM           4
#              RWB           2
#              LWB           1
#              RF            1
#              LDM           1
# Name: count, Length: 145, dtype: int64

# %% [markdown]
# ### SQL no Pandas

# %%
# off-topic: como melhorar o desempenho
# pip install modin
import modin.pandas as pd

# %%
import pandasql as ps

# %%
query = """
    select ID, Age, Name from fifa19 where Age > 33
"""

# %%
ps.sqldf(query, locals())
# Out:
#          ID  Age            Name
# 0      1179   40       G. Buffon
# 1        41   34         Iniesta
# 2    171919   35           Naldo
# 3    120533   35            Pepe
# 4     41236   36  Z. Ibrahimović
# ..      ...  ...             ...
# 888  244440   36     F. Nicastro
# 889   51963   44       T. Warner
# 890  100899   40     S. Phillips
# 891  182461   39       Zhou Ting
# 892   53748   44   K. Pilkington
#
# [893 rows x 3 columns]
